# %% [markdown]
# <a href="https://colab.research.google.com/github/ewertonmartinslopes/atividade-1/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# atividade 1

# %%
nome = "joao silva"
idade = 25
profissao = "desenvolvedor"
print("seu nome é:", nome)
print("sua idade:", idade)
print("sua profissão:", profissao)
# Out:
# seu nome é: joao silva
# sua idade: 25
# sua profissão: desenvolvedor

# %% [markdown]
# atividade 2

# %%
produto = "notebook"
marca = "dell"
preco = 4500.00
print(f"preco R$ {preco:.2f}")
print("produto:", produto)
print("marca:", marca)
# Out:
# preco R$ 4500.00
# produto: notebook
# marca: dell

# %% [markdown]
# atividade 3

# %%
num1 = 12
num2 = 6
soma = num1 + num2
subtracao = num1 - num2
mult = num1 * num2
div = num1 / num2
print("soma:", soma)
print("subtração:", subtracao)
print("mult:", mult)
print("div:", int(div))
# Out:
# soma: 18
# subtração: 6
# mult: 72
# div: 2

# %% [markdown]
# atividade 4

# %%
num1 = 7
num2 = 2
soma = num1 + num2
sub = num1 - num2
mult = num1 * num2
div = num1 / num2
potenciacao = num1 ** num2
print("soma:", soma)
print("sub:", sub)
print("mult:", mult)
print("div:", div)
print("potenciação:", potenciacao)
print("soma:", soma, "\n", "sub:", sub,"\n","mult:", mult, "\n", "div:", div, "potenciação:", potenciacao
      )
# Out:
# soma: 9
# sub: 5
# mult: 14
# div: 3.5
# potenciação: 49

# %% [markdown]
# atividade 5

# %%
num1 = 15
num2 = 5
soma =  num1 + num2
sub = num1 - num2
mult = num1 * num2
div = num1 / num2
potenciacao = num1 ** num2
print("soma:", soma, "\n", "sub:", sub, "\n", "mult:", mult, "\n", "div:", div, "\n", "potenciação:", potenciacao)
# Out:
# soma: 20
#  sub: 10
#  mult: 75
#  div: 3.0
#  potenciação: 759375

# %% [markdown]
# atividade 6 lista, tupla, dicionario

# %%
materias =  ['matemática', 'história', 'biologia']
notas = (8.5, 7.0, 9.2)
aluno = {'nome': ' carlos', 'idade': 21, 'curso': 'engenharia'}
print('matérias:', materias)
print('notas:', notas)
print('informações do aluno:', aluno)
# Out:
# matérias: ['matemática', 'história', 'biologia']
# notas: (8.5, 7.0, 9.2)
# informações do aluno: {'nome': ' carlos', 'idade': 21, 'curso': 'engenharia'}

# %% [markdown]
# atividade 7

# %%
acessorios =['step', 'airbag', 'dvd']
especificacoes = ('100cv', '30l', '110cv', '40l', '200cv', '40l')
carro = {'marca': 'ferrari', 'modelo': 'carrera', 'ano': 2026}
print('acessorios disponiveis', acessorios)
print('especificações em cv e tamanho do tanque', especificacoes)
print('informações do carro', carro)
# Out:
# acessorios disponiveis ['step', 'airbag', 'dvd']
# especificações em cv e tamanho do tanque ('100cv', '30l', '110cv', '40l', '200cv', '40l')
# informações do carro {'marca': 'ferrari', 'modelo': 'carrera', 'ano': 2026}

# %% [markdown]
# atividade 8

# %%
categorias = ['queijo', 'café', 'vinho']
